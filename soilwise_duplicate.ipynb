# %%
import requests
import pandas as pd
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import pdist, squareform

# %%
# Define the API endpoint URL
url = "https://soilwise-he.containers.wur.nl/cat/collections/metadata:main/items"

# list to gather all data through API requests
soilwise_data_json = []

#configuration
limit = 50 # the max items the API provides is 50

# loop through pages to retreive next part of data
for i in range(0,20):
    print(f'loop num {i}')
    offset = (limit*i) # extract next 50 items
    params = {'limit':limit, 
              'offset': offset,
             } 
    headers = {"Accept": "application/json"}
    
    # Make the API request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
         # Parse the JSON response
        soilwise_data_json = soilwise_data_json + data['features']
        print(f"id of first item extracted in this loop is {data['features'][0]['id']}")
    else:
        print(f"Failed to retrieve data: {response.status_code}")

soilwise_data_json[0]
# Out:
# loop num 0
# id of first item extracted in this loop is 2e755407-6fab-4b3f-832d-fa76ea535ab0
# loop num 1
# id of first item extracted in this loop is 0b88bd89-2f3d-4005-ac15-2c8c0c6ef614
# loop num 2
# id of first item extracted in this loop is 16111ae4-69ba-477f-a6aa-b6fc4c9c5d58
# loop num 3
# id of first item extracted in this loop is 1f9cac1e-ac71-4007-bec1-bdf979fa4403
# loop num 4
# id of first item extracted in this loop is 2a3d1b59-350c-4db6-a28c-ed31407c1fa4
# loop num 5
# id of first item extracted in this loop is 362a01d3-3af1-400d-9436-840779995a4d
# loop num 6
# id of first item extracted in this loop is 417ff2b0-229d-421f-9c41-25e838090eed
# loop num 7
# id of first item extracted in this loop is 4dd7c40f-0fb9-4229-aaee-408d118856f0
# loop num 8
# id of first item extracted in this loop is 58d1aa0b-864a-4cf7-98dc-5915ba659aa8
# loop num 9
# id of first item extracted in this loop is 6409f4c7-0683-4471-b8f6-17b6dc8b2291
# loop num 10
# id of first item extracted in this loop is d49218ae-a95a-403f-b5b8-e927df26260b
# loop num 11
# id of first item extracted in this loop is 7474507b-9697-45a8-8cdc-3e3aa65d8e2a
# loop num 12
# id of first item extracted in this loop is 82101aff-f824-41f2-b794-ddeb79c4b211
# loop num 13
# id of first item extracted in this loop is 8da97a96-6f5c-4780-8641-53e810393408
# loop num 14
# id of first item extracted in this loop is 9b296f99-f6a0-423c-9716-6a04fd2e502f
# loop num 15
# id of first item extracted in this loop is AF434BE2-57D6-47AB-8D5B-F47927184990
# loop num 16
# id of first item extracted in this loop is a97360fa-9b90-4258-a411-f68cf3e949b0
# loop num 17
# id of first item extracted in this loop is b7c7fb26-91fb-4718-96ca-ef8db836c1e7
# loop num 18
# id of first item extracted in this loop is c0f4f1ef-ddc4-40bf-a280-ad8404b3d59f
# loop num 19
# id of first item extracted in this loop is cf6cab85-ab9f-47c5-90a5-8df06bdb81c9
# {'id': '2e755407-6fab-4b3f-832d-fa76ea535ab0',
#  'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[9.14, 53.11],
#     [9.14, 54.96],
#     [10.77, 54.96],
#     [10.77, 53.11],
#     [9.14, 53.11]]]},
#  'time': '2024-06-20',
#  'properties': {'themes': [{'scheme': None, 'concepts': []},
#    {'scheme': None, 'concepts': []}],
#   'license': 'CC BY',
#   'updated': '2024-06-20',
#   'type': 'service',
#   'created': '2020-03-06',
#   'language': 'eng',
#   'title': "WMS Service of the dataset 'V140 Kiel: Geographical reference and description of trial plots'",
#   'description': "This WMS  Service includes spatial information used by datasets 'WMS Service of the dataset 'V140 Kiel: Geographical reference and description of trial plots''",
#   'formats': ['CSV'],
#   'keywords': ['infoMapAccessService',
#    'Soil',
#    'Organic amendments',
#    'Geographical information systems',
#    'Field experimentation',
#    'Farm area',
#    'data collection'],
#   'providers': [{'name': 'Steffen Rothardt',
#     'organization': 'CAU Kiel',
#     'positionName': 'Scientific staff',
#     'roles': [{'name': 'author'}],
#     'contactInfo': {'phone': {'work': '+494318804398'},
#      'email': {'work': 'rothardt@pflanzenbau.uni-kiel.de'},
#      'address': {'work': {'deliveryPoint': 'Hermann-Rodewald-Str. 9',
#        'city': 'Kiel',
#        'administrativeArea': 'Schleswig-Holstein',
#        'postalCode': '24118',
#        'country': 'Germany'}},
#      'url': None}},
#    {'name': 'Henning Kage',
#     'organization': 'CAU Kiel',
#     'positionName': 'Professor',
#     'roles': [{'name': 'supervisor'}],
#     'contactInfo': {'phone': {'work': '+494318804398'},
#      'email': {'work': 'kage@pflanzenbau.uni-kiel.de'},
#      'address': {'work': {'deliveryPoint': 'Hermann-Rodewald-Str. 9',
#        'city': 'Kiel',
#        'administrativeArea': 'Schleswig-Holstein',
#        'postalCode': '24118',
#        'country': 'Germany'}},
#      'url': None}},
#    {'name': 'BonaRes Data Centre',
#     'organization': 'Leibniz Centre for Agricultural Landscape Research (ZALF)',
#     'positionName': "Research Platform 'Data' - WG Geodata",
#     'roles': [{'name': 'publisher'}],
#     'contactInfo': {'phone': {'work': '+49 33432 82 171'},
#      'email': {'work': 'bonares-datenzentrum@zalf.de'},
#      'address': {'work': {'deliveryPoint': 'Eberswalder Strasse 84',
#        'city': 'Müncheberg',
#        'administrativeArea': 'Brandenburg',
#        'postalCode': '15374',
#        'country': 'Germany'}},
#      'url': None}},
#    {'name': 'Nicolas Brüggemann',
#     'organization': 'FZ Jülich',
#     'positionName': 'Professor',
#     'roles': [{'name': 'projectLeader'}],
#     'contactInfo': {'phone': {'work': None},
#      'email': {'work': 'n.brueggemann@fz-juelich.de'},
#      'address': {'work': {'deliveryPoint': None,
#        'city': None,
#        'administrativeArea': None,
#        'postalCode': None,
#        'country': None}},
#      'url': None}},
#    {'name': 'Nicolas Brüggemann',
#     'organization': 'FZ Jülich',
#     'positionName': 'Professor',
#     'roles': [{'name': 'projectLeader'}],
#     'contactInfo': {'phone': {'work': None},
#      'email': {'work': 'n.brueggemann@fz-juelich.de'},
#      'address': {'work': {'deliveryPoint': None,
#        'city': None,
#        'administrativeArea': None,
#        'postalCode': None,
#        'country': None}},
#      'url': None}}]},
#  'links': [{'href': 'https://maps.bonares.de/mapapps/resources/apps/bonares/index.html?lang=en&mid=2e755407-6fab-4b3f-832d-fa76ea535ab0',
#    'name': None,
#    'description': None,
#    'type': None,
#    'rel': 'information'},
#   {'href': 'https://maps.bonares.de/wss/service/ags-relay/ags/guest/arcgis/rest/services/Inplamint/ID5015UKielV140PlotDescription/MapServer/WMSServer?request=GetCapabilities&service=WMS',
#    'name': None,
#    'description': None,
#    'type': None},
#   {'href': 'https://maps.bonares.de/wss/service/ags-relay/ags/guest/arcgis/rest/services/Inplamint/ID5015UKielV140PlotDescription/MapServer/WMSServer?request=GetCapabilities&service=WMS',
#    'name': None,
#    'description': None,
#    'type': None},
#   {'href': 'https://maps.bonares.de/wss/service/ags-relay/ags/guest/arcgis/rest/services/Inplamint/ID5015UKielV140PlotDescription/MapServer/WMSServer?request=GetCapabilities&service=WMS',
#    'name': None,
#    'description': None,
#    'type': None},
#   {'href': 'https://maps.bonares.de/wss/service/ags-relay/ags/guest/arcgis/rest/services/Inplamint/ID5015UKielV140PlotDescription/MapServer/WMSServer?request=GetCapabilities&service=WMS',
#    'name': None,
#    'description': None,
#    'type': None},
#   {'href': 'https://metadata.bonares.de:443/smartEditor/preview/Inplamint_1_hohenschulen_v140_kiel.PNG',
#    'name': 'preview',
#    'description': 'Web image thumbnail (URL)',
#    'type': 'WWW:LINK-1.0-http--image-thumbnail',
#    'rel': 'preview'},
#   {'rel': 'self',
#    'type': 'application/geo+json',
#    'title': '2e755407-6fab-4b3f-832d-fa76ea535ab0',
#    'name': 'item',
#    'description': '2e755407-6fab-4b3f-832d-fa76ea535ab0',
#    'href': 'https://soilwise-he.containers.wur.nl/cat/collections/metadata:main/items/2e755407-6fab-4b3f-832d-fa76ea535ab0'},
#   {'rel': 'collection',
#    'type': 'application/json',
#    'title': 'Collection',
#    'name': 'collection',
#    'description': 'Collection',
#    'href': 'https://soilwise-he.containers.wur.nl/cat/collections/metadata:main'}]}

# %%
print(f"total number of items extracted is {len(soilwise_data_json)}")
# Out:
# total number of items extracted is 1000

# %%
# Extract the relevant fields for each item
extracted_data = []
# iterate through the json and extract the fields needed for each item
for item in soilwise_data_json:
    extracted_item = {
        'id': item['id'],
        'title': item['properties'].get('title', ""), # Use an empty string if field is not available
        'description': item['properties'].get('description', ""), # Use an empty string if field is not available
        'keywords': item['properties'].get('keywords',[]) # Use an empty list if field is not available
    }
    extracted_data.append(extracted_item)

# Convert to DataFrame
soilwise_data_df = pd.DataFrame(extracted_data)

# checking for dupicates:
print(f"number of rows of dataframe is {soilwise_data_df.shape[0]}")
soilwise_data_df = soilwise_data_df.drop_duplicates(subset=['id'])
print(f"number of rows of dataframe after dropping duplicates is {soilwise_data_df.shape[0]}")


soilwise_data_df
# Out:
# number of rows of dataframe is 1000
# number of rows of dataframe after dropping duplicates is 1000
#                                        id  \
# 0    2e755407-6fab-4b3f-832d-fa76ea535ab0
# 1    0007bad6-848d-4763-9813-d5ed21cde6ee
# 2    00682004-c6b9-4c1d-8b40-3afff8bbec69
# 3    0086CC52-6F67-4393-99BE-7D3AB1B84160
# 4    166e8d03-d047-4031-ad12-113c0acb0f60
# ..                                    ...
# 995  dd49a3c4-38a2-4695-be36-72ff9303487c
# 996  dda3c8ac-7248-4ea1-a633-de15b15180b3
# 997  dd41e401-ab56-40b2-bfa4-d82a899d972a
# 998  dd6a0c58-166a-4e79-82b0-f32051d14faa
# 999  de0ec281-9f57-44a5-b78e-5c60672d73fe
#
#                                                  title  \
# 0    WMS Service of the dataset 'V140 Kiel: Geograp...
# 1    Interactive effects of microplastics with othe...
# 2    SUSALPS temperature and volumetric soil water ...
# 3    Bodenübersichtskarte der Bundesrepublik Deutsc...
# 4    WMS Service of the dataset 'Impact of biopores...
# ..                                                 ...
# 995  Lysimeter data Rostock: P speciation of soil a...
# 996  Meteorological data, soil temperature and soil...
# 997  Web Map Service of the dataset 'Impact of diff...
# 998  Bee diversity in island-like habitats (kettle ...
# 999  Grinderwald / Rüdershausen / Ebergötzen – Sorp...
#
#                                            description  \
# 0    This WMS  Service includes spatial information...
# 1    Our study reveals the effects of GCFs on a soi...
# 2    Grassland is a precious good. Grassland contri...
# 3    Die hier vorgestellte Bodenübersichtskarte im ...
# 4    This WMS Service includes spatial information ...
# ..                                                 ...
# 995  The dataset contains P K-edge XANES data for s...
# 996  The data set was provided by the responsible p...
# 997  This Web Map Service includes spatial informat...
# 998  During June and July of 2017, wild bees were c...
# 999  This dataset includes laboratory batch sorptio...
#
#                                               keywords
# 0    [infoMapAccessService, Soil, Organic amendment...
# 1    [Soil, microplastics, opendata, Multiple level...
# 2    [environmental factors, water, Soil analysis, ...
# 3    [Boden, Soil, Bodenart, Bodenauslaugung, Boden...
# 4                               [infoMapAccessService]
# ..                                                 ...
# 995  [Soil, Phosphorus, Spectroscopy, Boden, P K-ed...
# 996  [meteorological observations, conventional agr...
# 997  [infoMapAccessService, Soil, phosphorus, mycor...
# 998  [soil, opendata, pollination service, metacomm...
# 999  [Soil, forest soils, subsoil, carbon cycle, di...
#
# [1000 rows x 4 columns]

# %%
# new columns to generate embeddings of original columns
soilwise_data_df['embedding_title'] = soilwise_data_df.title
soilwise_data_df['embedding_description'] = soilwise_data_df.description
soilwise_data_df['embedding_keywords'] = soilwise_data_df['keywords'].apply(lambda x: ', '.join(x))

soilwise_data_df
# Out:
#                                        id  \
# 0    2e755407-6fab-4b3f-832d-fa76ea535ab0
# 1    0007bad6-848d-4763-9813-d5ed21cde6ee
# 2    00682004-c6b9-4c1d-8b40-3afff8bbec69
# 3    0086CC52-6F67-4393-99BE-7D3AB1B84160
# 4    166e8d03-d047-4031-ad12-113c0acb0f60
# ..                                    ...
# 995  dd49a3c4-38a2-4695-be36-72ff9303487c
# 996  dda3c8ac-7248-4ea1-a633-de15b15180b3
# 997  dd41e401-ab56-40b2-bfa4-d82a899d972a
# 998  dd6a0c58-166a-4e79-82b0-f32051d14faa
# 999  de0ec281-9f57-44a5-b78e-5c60672d73fe
#
#                                                  title  \
# 0    WMS Service of the dataset 'V140 Kiel: Geograp...
# 1    Interactive effects of microplastics with othe...
# 2    SUSALPS temperature and volumetric soil water ...
# 3    Bodenübersichtskarte der Bundesrepublik Deutsc...
# 4    WMS Service of the dataset 'Impact of biopores...
# ..                                                 ...
# 995  Lysimeter data Rostock: P speciation of soil a...
# 996  Meteorological data, soil temperature and soil...
# 997  Web Map Service of the dataset 'Impact of diff...
# 998  Bee diversity in island-like habitats (kettle ...
# 999  Grinderwald / Rüdershausen / Ebergötzen – Sorp...
#
#                                            description  \
# 0    This WMS  Service includes spatial information...
# 1    Our study reveals the effects of GCFs on a soi...
# 2    Grassland is a precious good. Grassland contri...
# 3    Die hier vorgestellte Bodenübersichtskarte im ...
# 4    This WMS Service includes spatial information ...
# ..                                                 ...
# 995  The dataset contains P K-edge XANES data for s...
# 996  The data set was provided by the responsible p...
# 997  This Web Map Service includes spatial informat...
# 998  During June and July of 2017, wild bees were c...
# 999  This dataset includes laboratory batch sorptio...
#
#                                               keywords  \
# 0    [infoMapAccessService, Soil, Organic amendment...
# 1    [Soil, microplastics, opendata, Multiple level...
# 2    [environmental factors, water, Soil analysis, ...
# 3    [Boden, Soil, Bodenart, Bodenauslaugung, Boden...
# 4                               [infoMapAccessService]
# ..                                                 ...
# 995  [Soil, Phosphorus, Spectroscopy, Boden, P K-ed...
# 996  [meteorological observations, conventional agr...
# 997  [infoMapAccessService, Soil, phosphorus, mycor...
# 998  [soil, opendata, pollination service, metacomm...
# 999  [Soil, forest soils, subsoil, carbon cycle, di...
#
#                                        embedding_title  \
# 0    WMS Service of the dataset 'V140 Kiel: Geograp...
# 1    Interactive effects of microplastics with othe...
# 2    SUSALPS temperature and volumetric soil water ...
# 3    Bodenübersichtskarte der Bundesrepublik Deutsc...
# 4    WMS Service of the dataset 'Impact of biopores...
# ..                                                 ...
# 995  Lysimeter data Rostock: P speciation of soil a...
# 996  Meteorological data, soil temperature and soil...
# 997  Web Map Service of the dataset 'Impact of diff...
# 998  Bee diversity in island-like habitats (kettle ...
# 999  Grinderwald / Rüdershausen / Ebergötzen – Sorp...
#
#                                  embedding_description  \
# 0    This WMS  Service includes spatial information...
# 1    Our study reveals the effects of GCFs on a soi...
# 2    Grassland is a precious good. Grassland contri...
# 3    Die hier vorgestellte Bodenübersichtskarte im ...
# 4    This WMS Service includes spatial information ...
# ..                                                 ...
# 995  The dataset contains P K-edge XANES data for s...
# 996  The data set was provided by the responsible p...
# 997  This Web Map Service includes spatial informat...
# 998  During June and July of 2017, wild bees were c...
# 999  This dataset includes laboratory batch sorptio...
#
#                                     embedding_keywords
# 0    infoMapAccessService, Soil, Organic amendments...
# 1    Soil, microplastics, opendata, Multiple level;...
# 2    environmental factors, water, Soil analysis, S...
# 3    Boden, Soil, Bodenart, Bodenauslaugung, Bodenb...
# 4                                 infoMapAccessService
# ..                                                 ...
# 995  Soil, Phosphorus, Spectroscopy, Boden, P K-edg...
# 996  meteorological observations, conventional agri...
# 997  infoMapAccessService, Soil, phosphorus, mycorr...
# 998  soil, opendata, pollination service, metacommu...
# 999  Soil, forest soils, subsoil, carbon cycle, dis...
#
# [1000 rows x 7 columns]

# %%
# multiple possibilities to convert text into contextual embeddings, current option is using transformers available via HugginFace platform (BERT, DISTILBERT, ... -> free),
# other options are to use contextual-richer LLM's (e.g. paying: GP or free LLama3 -> more resources needed! overkill, added value?)

# Set up with pre-trained model
model_name = 'distilbert-base-uncased'  # other models like 'bert-base-uncased' are also possible

# load tokenizer for selected model
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
except Exception as e:
    print(f"Error loading tokenizer: {e}")
    raise

# load selected model
try:
    model = AutoModel.from_pretrained(model_name)
except Exception as e:
    print(f"Error loading model: {e}")
    raise

# Function to convert text into embeddings, each word is converted into vector and result is mean of all word-vectors. Other approaches are also possible, e.g. on sentence level, taking context of other words in sentence into account
def get_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
    outputs = model(**inputs)
    # Take the mean of the token/word embeddings
    embeddings = torch.mean(outputs.last_hidden_state, dim=1)
    return embeddings.detach().numpy()

# Apply the function to the DataFrame
soilwise_data_df['embedding_title'] = soilwise_data_df['embedding_title'].apply(get_embeddings)
soilwise_data_df['embedding_description'] = soilwise_data_df['embedding_description'].apply(get_embeddings)
soilwise_data_df['embedding_keywords'] = soilwise_data_df['embedding_keywords'].apply(get_embeddings)

soilwise_data_df
# Out:
# C:\Users\nberkvens\AppData\Local\anaconda3\envs\tensorflow_gee_3\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#                                        id  \
# 0    2e755407-6fab-4b3f-832d-fa76ea535ab0
# 1    0007bad6-848d-4763-9813-d5ed21cde6ee
# 2    00682004-c6b9-4c1d-8b40-3afff8bbec69
# 3    0086CC52-6F67-4393-99BE-7D3AB1B84160
# 4    166e8d03-d047-4031-ad12-113c0acb0f60
# ..                                    ...
# 995  dd49a3c4-38a2-4695-be36-72ff9303487c
# 996  dda3c8ac-7248-4ea1-a633-de15b15180b3
# 997  dd41e401-ab56-40b2-bfa4-d82a899d972a
# 998  dd6a0c58-166a-4e79-82b0-f32051d14faa
# 999  de0ec281-9f57-44a5-b78e-5c60672d73fe
#
#                                                  title  \
# 0    WMS Service of the dataset 'V140 Kiel: Geograp...
# 1    Interactive effects of microplastics with othe...
# 2    SUSALPS temperature and volumetric soil water ...
# 3    Bodenübersichtskarte der Bundesrepublik Deutsc...
# 4    WMS Service of the dataset 'Impact of biopores...
# ..                                                 ...
# 995  Lysimeter data Rostock: P speciation of soil a...
# 996  Meteorological data, soil temperature and soil...
# 997  Web Map Service of the dataset 'Impact of diff...
# 998  Bee diversity in island-like habitats (kettle ...
# 999  Grinderwald / Rüdershausen / Ebergötzen – Sorp...
#
#                                            description  \
# 0    This WMS  Service includes spatial information...
# 1    Our study reveals the effects of GCFs on a soi...
# 2    Grassland is a precious good. Grassland contri...
# 3    Die hier vorgestellte Bodenübersichtskarte im ...
# 4    This WMS Service includes spatial information ...
# ..                                                 ...
# 995  The dataset contains P K-edge XANES data for s...
# 996  The data set was provided by the responsible p...
# 997  This Web Map Service includes spatial informat...
# 998  During June and July of 2017, wild bees were c...
# 999  This dataset includes laboratory batch sorptio...
#
#                                               keywords  \
# 0    [infoMapAccessService, Soil, Organic amendment...
# 1    [Soil, microplastics, opendata, Multiple level...
# 2    [environmental factors, water, Soil analysis, ...
# 3    [Boden, Soil, Bodenart, Bodenauslaugung, Boden...
# 4                               [infoMapAccessService]
# ..                                                 ...
# 995  [Soil, Phosphorus, Spectroscopy, Boden, P K-ed...
# 996  [meteorological observations, conventional agr...
# 997  [infoMapAccessService, Soil, phosphorus, mycor...
# 998  [soil, opendata, pollination service, metacomm...
# 999  [Soil, forest soils, subsoil, carbon cycle, di...
#
#                                        embedding_title  \
# 0    [[-0.26295176, -0.05457902, 0.18401955, -0.024...
# 1    [[-0.033952005, 0.108728155, -0.06883621, 0.26...
# 2    [[-0.43514106, -0.17300248, 0.25394157, 0.0440...
# 3    [[-0.107180506, 0.05131866, -0.004376183, -0.0...
# 4    [[-0.30051106, 0.010823536, -0.00085008406, 0....
# ..                                                 ...
# 995  [[-0.2660006, -0.0024695226, 0.1961377, 0.0865...
# 996  [[-0.19836816, 0.18848011, 0.23790435, 0.06357...
# 997  [[-0.28205073, 0.06666757, 0.0024443802, 0.111...
# 998  [[-0.13129774, 0.066172116, -0.09157369, 0.034...
# 999  [[-0.2100621, 0.045851577, 0.28211123, -0.0494...
#
#                                  embedding_description  \
# 0    [[-0.16696317, 0.023651835, 0.40922853, 0.0611...
# 1    [[-0.39372316, 0.16548389, 0.23728773, 0.02120...
# 2    [[-0.35968208, 0.10235999, 0.27212578, 0.02710...
# 3    [[-0.43826976, 0.0939387, 0.19622806, -0.09944...
# 4    [[-0.17242524, 0.071774796, 0.23867568, 0.0861...
# ..                                                 ...
# 995  [[-0.3732139, 0.1163093, 0.19196309, 0.0178190...
# 996  [[-0.2669382, 0.03301047, 0.35249576, 0.100728...
# 997  [[-0.22959174, 0.11016257, 0.07057317, 0.17223...
# 998  [[-0.18780026, 0.14625682, 0.07552566, 0.04365...
# 999  [[-0.29601556, -0.021467844, 0.26272577, 0.136...
#
#                                     embedding_keywords
# 0    [[-0.016777532, 0.19714673, 0.07908519, 0.2453...
# 1    [[-0.22446337, 0.1571082, 0.15740468, 0.091955...
# 2    [[-0.17351066, 0.57065666, 0.2568822, 0.093950...
# 3    [[-0.16472208, 0.16405283, 0.31736588, -0.0633...
# 4    [[0.030550646, -0.16269122, 0.0698429, 0.25449...
# ..                                                 ...
# 995  [[-0.10512679, 0.29478765, 0.21147047, -0.0255...
# 996  [[-0.09898419, 0.348396, 0.3860768, 0.01230619...
# 997  [[-0.14000942, 0.37072366, 0.2850479, 0.288238...
# 998  [[-0.09354025, 0.101906545, 0.131732, 0.037236...
# 999  [[-0.106830254, 0.2363798, 0.3219621, 0.045173...
#
# [1000 rows x 7 columns]

# %%
# Extract the list of embeddings
embeddings_title = np.vstack(soilwise_data_df['embedding_title'].values)
embeddings_description = np.vstack(soilwise_data_df['embedding_description'].values)
embeddings_keywords = np.vstack(soilwise_data_df['embedding_keywords'].values)

embeddings_title
# Out:
# array([[-0.26295176, -0.05457902,  0.18401955, ..., -0.15498509,
#         -0.03641442, -0.01700304],
#        [-0.03395201,  0.10872816, -0.06883621, ..., -0.39589286,
#         -0.35345253,  0.07227551],
#        [-0.43514106, -0.17300248,  0.25394157, ..., -0.16051476,
#         -0.0865849 ,  0.22067128],
#        ...,
#        [-0.28205073,  0.06666757,  0.00244438, ..., -0.40080816,
#         -0.00988611, -0.13360786],
#        [-0.13129774,  0.06617212, -0.09157369, ..., -0.16610388,
#         -0.11972532,  0.04935502],
#        [-0.2100621 ,  0.04585158,  0.28211123, ..., -0.04859553,
#          0.00249721, -0.04730187]], dtype=float32)

# %%
# multiple ways to determine similarity based on 'distance'/'direction' between vectors (Euclidean distance, cosine similarity, manhattan distance, jaccard similarity

# Calculate cosine similarity
sim_matrix_title = cosine_similarity(embeddings_title)
sim_matrix_description = cosine_similarity(embeddings_description)
sim_matrix_keywords = cosine_similarity(embeddings_keywords)

sim_matrix_title
# Out:
# array([[0.9999998 , 0.72755253, 0.8335133 , ..., 0.84243417, 0.8454625 ,
#         0.72303736],
#        [0.72755253, 0.99999976, 0.82303673, ..., 0.8568301 , 0.8264514 ,
#         0.6822989 ],
#        [0.8335133 , 0.82303673, 1.0000001 , ..., 0.8538825 , 0.818401  ,
#         0.7596561 ],
#        ...,
#        [0.84243417, 0.8568301 , 0.8538825 , ..., 1.0000001 , 0.88914436,
#         0.70687485],
#        [0.8454625 , 0.8264514 , 0.818401  , ..., 0.88914436, 1.0000004 ,
#         0.68818754],
#        [0.72303736, 0.6822989 , 0.7596561 , ..., 0.70687485, 0.68818754,
#         1.0000002 ]], dtype=float32)

# %%
# Convert the matrices to a DataFrame for better readability
sim_title_df = pd.DataFrame(sim_matrix_title, index=soilwise_data_df.rename(columns={'id':'id_1'}).id_1, columns=soilwise_data_df.rename(columns={'id':'id_2'}).id_2)
sim_description_df = pd.DataFrame(sim_matrix_description, index=soilwise_data_df.rename(columns={'id':'id_1'}).id_1, columns=soilwise_data_df.rename(columns={'id':'id_2'}).id_2)
sim_keywords_df = pd.DataFrame(sim_matrix_keywords, index=soilwise_data_df.rename(columns={'id':'id_1'}).id_1, columns=soilwise_data_df.rename(columns={'id':'id_2'}).id_2)

sim_title_df
# Out:
# id_2                                  2e755407-6fab-4b3f-832d-fa76ea535ab0  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              1.000000
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.727553
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.833513
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.752005
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.885135
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.861564
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.821779
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.842434
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.845463
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.723037
#
# id_2                                  0007bad6-848d-4763-9813-d5ed21cde6ee  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.727553
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              1.000000
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.823037
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.617708
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.848116
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.810022
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.773859
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.856830
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.826451
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.682299
#
# id_2                                  00682004-c6b9-4c1d-8b40-3afff8bbec69  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.833513
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.823037
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              1.000000
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.719942
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.866733
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.895643
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.855165
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.853882
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.818401
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.759656
#
# id_2                                  0086CC52-6F67-4393-99BE-7D3AB1B84160  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.752005
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.617708
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.719942
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              1.000000
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.701170
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.697186
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.668543
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.684325
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.677488
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.775577
#
# id_2                                  166e8d03-d047-4031-ad12-113c0acb0f60  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.885135
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.848116
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.866733
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.701170
# 166e8d03-d047-4031-ad12-113c0acb0f60                              1.000000
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.869020
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.831670
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.928040
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.893725
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.713759
#
# id_2                                  3418ee89-8331-49a9-b3d2-e14b8fde88be  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.924839
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.722251
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.799670
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.718171
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.858879
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.842087
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.764388
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.815296
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.814110
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.740148
#
# id_2                                  01da627d-9ad7-4414-9f32-222a139c2407  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.769051
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.804379
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.822063
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.637447
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.834621
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.823721
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.780935
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.837038
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.829861
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.749725
#
# id_2                                  025b61e6-5e9b-4c03-9e48-fa22be02106f  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.813880
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.693615
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.755467
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.706693
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.744966
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.808952
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.740569
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.758880
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.757532
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.724729
#
# id_2                                  00bee634-47e6-490b-89ba-2464c9f09c31  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.813501
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.802788
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.840252
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.707506
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.862810
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.855556
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.819321
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.905640
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.847048
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.740263
#
# id_2                                  0160f3e2-aa36-431c-96f7-871dc41e5f8c  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.863694
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.851099
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.888579
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.718613
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.913519
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.870155
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.851006
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.909556
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.873680
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.773084
#
# id_2                                  ...  \
# id_1                                  ...
# 2e755407-6fab-4b3f-832d-fa76ea535ab0  ...
# 0007bad6-848d-4763-9813-d5ed21cde6ee  ...
# 00682004-c6b9-4c1d-8b40-3afff8bbec69  ...
# 0086CC52-6F67-4393-99BE-7D3AB1B84160  ...
# 166e8d03-d047-4031-ad12-113c0acb0f60  ...
# ...                                   ...
# dd49a3c4-38a2-4695-be36-72ff9303487c  ...
# dda3c8ac-7248-4ea1-a633-de15b15180b3  ...
# dd41e401-ab56-40b2-bfa4-d82a899d972a  ...
# dd6a0c58-166a-4e79-82b0-f32051d14faa  ...
# de0ec281-9f57-44a5-b78e-5c60672d73fe  ...
#
# id_2                                  dc115e5b-b27a-494b-9054-21ecdbda8d9f  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.742557
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.828225
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.815610
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.639714
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.827324
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.837489
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.724773
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.866802
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.845101
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.701012
#
# id_2                                  dc7d8d5f-3448-4f94-8fbd-14a4979a32ab  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.507263
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.518291
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.555473
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.494674
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.560622
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.525811
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.494806
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.512407
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.538308
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.548887
#
# id_2                                  dcc61b52-3767-4d29-bcf0-26c5cec0afd0  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.827588
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.832834
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.802406
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.650903
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.837335
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.843361
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.813475
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.844981
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.842849
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.662031
#
# id_2                                  dc95094f-5f65-433f-805d-16642da2616a  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.844388
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.800646
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.979098
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.744184
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.856243
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.904782
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.871425
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.839624
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.811897
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.792756
#
# id_2                                  dd1948d5-525d-4705-851b-acd45f92eb8b  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.796979
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.783742
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.822648
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.639187
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.822379
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.863966
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.759831
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.823071
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.821389
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.690105
#
# id_2                                  dd49a3c4-38a2-4695-be36-72ff9303487c  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.861564
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.810022
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.895643
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.697186
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.869020
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              1.000000
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.843859
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.871039
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.846370
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.748114
#
# id_2                                  dda3c8ac-7248-4ea1-a633-de15b15180b3  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.821779
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.773859
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.855165
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.668543
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.831670
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.843859
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              1.000000
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.811497
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.799589
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.680493
#
# id_2                                  dd41e401-ab56-40b2-bfa4-d82a899d972a  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.842434
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.856830
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.853882
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.684325
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.928040
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.871039
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.811497
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              1.000000
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.889144
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.706875
#
# id_2                                  dd6a0c58-166a-4e79-82b0-f32051d14faa  \
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.845463
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.826451
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.818401
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.677488
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.893725
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.846370
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.799589
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.889144
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              1.000000
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              0.688188
#
# id_2                                  de0ec281-9f57-44a5-b78e-5c60672d73fe
# id_1
# 2e755407-6fab-4b3f-832d-fa76ea535ab0                              0.723037
# 0007bad6-848d-4763-9813-d5ed21cde6ee                              0.682299
# 00682004-c6b9-4c1d-8b40-3afff8bbec69                              0.759656
# 0086CC52-6F67-4393-99BE-7D3AB1B84160                              0.775577
# 166e8d03-d047-4031-ad12-113c0acb0f60                              0.713759
# ...                                                                    ...
# dd49a3c4-38a2-4695-be36-72ff9303487c                              0.748114
# dda3c8ac-7248-4ea1-a633-de15b15180b3                              0.680493
# dd41e401-ab56-40b2-bfa4-d82a899d972a                              0.706875
# dd6a0c58-166a-4e79-82b0-f32051d14faa                              0.688188
# de0ec281-9f57-44a5-b78e-5c60672d73fe                              1.000000
#
# [1000 rows x 1000 columns]

# %%
# Stack the DataFrames and reset the index
stacked_sim_title_df = sim_title_df.stack().reset_index()
stacked_sim_description_df = sim_description_df.stack().reset_index()
stacked_sim_keywords_df = sim_keywords_df.stack().reset_index()
# Rename the columns
stacked_sim_title_df.columns = ['id_1','id_2','similarity_metric']
stacked_sim_description_df.columns = ['id_1','id_2','similarity_metric']
stacked_sim_keywords_df.columns = ['id_1','id_2','similarity_metric']
# Filter out self-similarity (similarity of items with themselves)
stacked_sim_title_df = stacked_sim_title_df[stacked_sim_title_df['id_1'] != stacked_sim_title_df['id_2']]
stacked_sim_description_df = stacked_sim_description_df[stacked_sim_description_df['id_1'] != stacked_sim_description_df['id_2']]
stacked_sim_keywords_df = stacked_sim_keywords_df[stacked_sim_keywords_df['id_1'] != stacked_sim_keywords_df['id_2']]
stacked_sim_title_df = stacked_sim_title_df.sort_values(by=['similarity_metric'], ascending=False)
stacked_sim_description_df = stacked_sim_description_df.sort_values(by=['similarity_metric'], ascending=False)
stacked_sim_keywords_df = stacked_sim_keywords_df.sort_values(by=['similarity_metric'], ascending=False)
stacked_sim_title_df
# Out:
#                                         id_1  \
# 929221  c9a6def1-d330-475f-bf52-4931ae2b8bcf
# 221929  2e48504f-4ae9-4400-b5fe-128b03863710
# 99097   500e7063-e828-4e82-b533-91c80a010817
# 365477  5187f8c5-38ef-4b07-bc26-a5e257a8ef59
# 962958  d3e51946-2c46-4e5b-af86-800af4e21e3d
# ...                                      ...
# 317477  44e6b58a-78fd-40bd-ac88-84974676bfca
# 590477  7fb4144f-f591-486f-b0db-ddad9f192932
# 365590  5187f8c5-38ef-4b07-bc26-a5e257a8ef59
# 477590  68749995-c4bf-4f80-94e5-43c2291c99be
# 590365  7fb4144f-f591-486f-b0db-ddad9f192932
#
#                                         id_2  similarity_metric
# 929221  2e48504f-4ae9-4400-b5fe-128b03863710           1.000000
# 221929  c9a6def1-d330-475f-bf52-4931ae2b8bcf           1.000000
# 99097   551bd06c-9f14-4737-809d-32250a010852           1.000000
# 365477  68749995-c4bf-4f80-94e5-43c2291c99be           1.000000
# 962958  d36ad69a-42ed-42b8-be24-5492802fa876           1.000000
# ...                                      ...                ...
# 317477  68749995-c4bf-4f80-94e5-43c2291c99be           0.201143
# 590477  68749995-c4bf-4f80-94e5-43c2291c99be           0.201026
# 365590  7fb4144f-f591-486f-b0db-ddad9f192932           0.201026
# 477590  7fb4144f-f591-486f-b0db-ddad9f192932           0.201026
# 590365  5187f8c5-38ef-4b07-bc26-a5e257a8ef59           0.201026
#
# [999000 rows x 3 columns]

# %%
# merge extra info about title etc.
# title
stacked_sim_title_df = stacked_sim_title_df.merge(soilwise_data_df[['id','title','description','keywords']], how='left', left_on='id_1', right_on='id')
stacked_sim_title_df = stacked_sim_title_df.merge(soilwise_data_df[['id','title','description','keywords']], how='left', left_on='id_2', right_on='id')
stacked_sim_title_df = stacked_sim_title_df.rename(columns={'title_x':'title_1','description_x':'description_1','keywords_x':'keywords_1','title_y':'title_2','description_y':'description_2','keywords_y':'keywords_2','similarity_metric':'similarity_metric_title'})
stacked_sim_title_df = stacked_sim_title_df[['similarity_metric_title','id_1','title_1','description_1','keywords_1','id_2','title_2','description_2','keywords_2']]
# description
stacked_sim_description_df = stacked_sim_description_df.merge(soilwise_data_df[['id']], how='left', left_on='id_1', right_on='id')
stacked_sim_description_df = stacked_sim_description_df.merge(soilwise_data_df[['id']], how='left', left_on='id_2', right_on='id')
stacked_sim_description_df = stacked_sim_description_df.rename(columns={'similarity_metric':'similarity_metric_description'})
stacked_sim_description_df = stacked_sim_description_df[['similarity_metric_description','id_1','id_2']]
# keywords
stacked_sim_keywords_df = stacked_sim_keywords_df.merge(soilwise_data_df[['id']], how='left', left_on='id_1', right_on='id')
stacked_sim_keywords_df = stacked_sim_keywords_df.merge(soilwise_data_df[['id']], how='left', left_on='id_2', right_on='id')
stacked_sim_keywords_df = stacked_sim_keywords_df.rename(columns={'similarity_metric':'similarity_metric_keywords'})
stacked_sim_keywords_df = stacked_sim_keywords_df[['similarity_metric_keywords','id_1','id_2']]

# merge all dataframes together
stacked_sim_df = pd.merge(left=stacked_sim_title_df, right=stacked_sim_description_df, how='left', left_on=['id_1', 'id_2'], right_on=['id_1', 'id_2'])
stacked_sim_df = pd.merge(left=stacked_sim_df, right=stacked_sim_keywords_df, how='left', left_on=['id_1', 'id_2'], right_on=['id_1', 'id_2'])
# rearrange
stacked_sim_df = stacked_sim_df[['similarity_metric_title','similarity_metric_description','similarity_metric_keywords','id_1','title_1','description_1','keywords_1','id_2','title_2','description_2','keywords_2']]

stacked_sim_df
# Out:
#         similarity_metric_title  similarity_metric_description  \
# 0                      1.000000                       0.999369
# 1                      1.000000                       0.999369
# 2                      1.000000                       0.838298
# 3                      1.000000                       1.000000
# 4                      1.000000                       0.774162
# ...                         ...                            ...
# 998995                 0.201143                       0.287283
# 998996                 0.201026                       0.270357
# 998997                 0.201026                       0.270357
# 998998                 0.201026                       0.270357
# 998999                 0.201026                       0.270357
#
#         similarity_metric_keywords                                  id_1  \
# 0                         0.788131  c9a6def1-d330-475f-bf52-4931ae2b8bcf
# 1                         0.788131  2e48504f-4ae9-4400-b5fe-128b03863710
# 2                         0.968593  500e7063-e828-4e82-b533-91c80a010817
# 3                         1.000000  5187f8c5-38ef-4b07-bc26-a5e257a8ef59
# 4                         1.000000  d3e51946-2c46-4e5b-af86-800af4e21e3d
# ...                            ...                                   ...
# 998995                    0.707676  44e6b58a-78fd-40bd-ac88-84974676bfca
# 998996                    0.707676  7fb4144f-f591-486f-b0db-ddad9f192932
# 998997                    0.707676  5187f8c5-38ef-4b07-bc26-a5e257a8ef59
# 998998                    0.707676  68749995-c4bf-4f80-94e5-43c2291c99be
# 998999                    0.707676  7fb4144f-f591-486f-b0db-ddad9f192932
#
#                                                   title_1  \
# 0       Proximal soil sensing data from the RapidMappe...
# 1       Proximal soil sensing data from the RapidMappe...
# 2                                   Půdní mapa 1 : 50 000
# 3                                                       |
# 4       Sugar beet time series experiment (V465) for c...
# ...                                                   ...
# 998995  Abundance of different microorganism groups in...
# 998996  Abundance of different microorganism groups in...
# 998997                                                  |
# 998998                                                  |
# 998999  Abundance of different microorganism groups in...
#
#                                             description_1  \
# 0       Proximal soil sensing data were collected by a...
# 1       Proximal soil sensing data were collected by a...
# 2       Mapy zobrazují půdní pokryv České republiky. V...
# 3                                                       |
# 4       This table contains observations of vegetation...
# ...                                                   ...
# 998995  The table contains the abundances of various b...
# 998996  The table contains the abundances of various b...
# 998997                                                  |
# 998998                                                  |
# 998999  The table contains the abundances of various b...
#
#                                                keywords_1  \
# 0       [Soil, soil pH, opendata, Proximal Soil Sensin...
# 1                                 [Soil, opendata, Boden]
# 2       [Půda, půdy, půda, typ půdní, mapa půdní, les,...
# 3                           [Boden, infoMapAccessService]
# 4       [Soil, sugar beet, crop yield, irrigation, nit...
# ...                                                   ...
# 998995  [Soil, maize, field experimentation, soil micr...
# 998996  [Soil, maize, field experimentation, soil micr...
# 998997                      [Boden, infoMapAccessService]
# 998998                      [Boden, infoMapAccessService]
# 998999  [Soil, maize, field experimentation, soil micr...
#
#                                         id_2  \
# 0       2e48504f-4ae9-4400-b5fe-128b03863710
# 1       c9a6def1-d330-475f-bf52-4931ae2b8bcf
# 2       551bd06c-9f14-4737-809d-32250a010852
# 3       68749995-c4bf-4f80-94e5-43c2291c99be
# 4       d36ad69a-42ed-42b8-be24-5492802fa876
# ...                                      ...
# 998995  68749995-c4bf-4f80-94e5-43c2291c99be
# 998996  68749995-c4bf-4f80-94e5-43c2291c99be
# 998997  7fb4144f-f591-486f-b0db-ddad9f192932
# 998998  7fb4144f-f591-486f-b0db-ddad9f192932
# 998999  5187f8c5-38ef-4b07-bc26-a5e257a8ef59
#
#                                                   title_2  \
# 0       Proximal soil sensing data from the RapidMappe...
# 1       Proximal soil sensing data from the RapidMappe...
# 2                                   Půdní mapa 1 : 50 000
# 3                                                       |
# 4       Sugar beet time series experiment (V465) for c...
# ...                                                   ...
# 998995                                                  |
# 998996                                                  |
# 998997  Abundance of different microorganism groups in...
# 998998  Abundance of different microorganism groups in...
# 998999                                                  |
#
#                                             description_2  \
# 0       Proximal soil sensing data were collected by a...
# 1       Proximal soil sensing data were collected by a...
# 2       INSPIRE prohlížecí služba zpřístupňuje půdní m...
# 3                                                       |
# 4       To create a holistic data set for the verifica...
# ...                                                   ...
# 998995                                                  |
# 998996                                                  |
# 998997  The table contains the abundances of various b...
# 998998  The table contains the abundances of various b...
# 998999                                                  |
#
#                                                keywords_2
# 0                                 [Soil, opendata, Boden]
# 1       [Soil, soil pH, opendata, Proximal Soil Sensin...
# 2       [půdy, Půda, mapa půdní, půda, typ půdní, mapa...
# 3                           [Boden, infoMapAccessService]
# 4       [Soil, sugar beet, crop yield, irrigation, nit...
# ...                                                   ...
# 998995                      [Boden, infoMapAccessService]
# 998996                      [Boden, infoMapAccessService]
# 998997  [Soil, maize, field experimentation, soil micr...
# 998998  [Soil, maize, field experimentation, soil micr...
# 998999                      [Boden, infoMapAccessService]
#
# [999000 rows x 11 columns]

# %%
# Create a new column with the maximum value of columns a, b, and c
stacked_sim_df['max_value'] = stacked_sim_df[['similarity_metric_title','similarity_metric_description','similarity_metric_keywords']].max(axis=1)

# Sort the DataFrame by the new column
# to minimalize the size of the dataframe, only select rows where at least one of the similarities is 1 
print(f'number of rows in dataframe is: {stacked_sim_df.shape[0]}')
stacked_sim_df = stacked_sim_df[stacked_sim_df.max_value == 1]
print(f'number of rows in dataframe only select rows where at least one of the similarities is 1: {stacked_sim_df.shape[0]}')
stacked_sim_df = stacked_sim_df.sort_values(by=['max_value','similarity_metric_title','similarity_metric_description','similarity_metric_keywords'], ascending=[False, False, False, False]).drop(columns='max_value')

stacked_sim_df
# Out:
# number of rows in dataframe is: 999000
# number of rows in dataframe only select rows where at least one of the similarities is 1: 1182
#         similarity_metric_title  similarity_metric_description  \
# 3                      1.000000                       1.000000
# 8                      1.000000                       1.000000
# 6                      1.000000                       0.999322
# 11                     1.000000                       0.999322
# 7                      1.000000                       0.987513
# ...                         ...                            ...
# 594961                 0.771850                       0.914437
# 838076                 0.691082                       0.885626
# 838077                 0.691082                       0.885626
# 842448                 0.688910                       0.906683
# 842449                 0.688910                       0.906683
#
#         similarity_metric_keywords                                  id_1  \
# 3                         1.000000  5187f8c5-38ef-4b07-bc26-a5e257a8ef59
# 8                         1.000000  68749995-c4bf-4f80-94e5-43c2291c99be
# 6                         1.000000  b8311ee8-4b8f-421a-aeac-2b4f0d4beff8
# 11                        1.000000  7a740815-f3bf-461f-a8d3-b7e274d3aac2
# 7                         0.970356  4b2b65c6-ff50-4669-99cc-ace343de3548
# ...                            ...                                   ...
# 594961                    1.000000  68B4F032-A0CE-4B47-89C2-23DB80414102
# 838076                    1.000000  6B346278-D020-48BE-9617-CE8BA1513308
# 838077                    1.000000  43ACDDFF-4F47-443E-B697-D36330486A75
# 842448                    1.000000  68B4F032-A0CE-4B47-89C2-23DB80414102
# 842449                    1.000000  6B346278-D020-48BE-9617-CE8BA1513308
#
#                                                   title_1  \
# 3                                                       |
# 8                                                       |
# 6       On-the-go gamma spectra for the site “Düren” f...
# 11      On-the-go gamma spectra for the site “Düren” f...
# 7       Scaling with ranked subsampling (SRS) algorith...
# ...                                                   ...
# 594961   INSPIRE - Annex III - Soil - Soil map (1:25.000)
# 838076                     Topsoil Organic Carbon Content
# 838077  INSPIRE - Annex III - Soil - Soil map (1:100.000)
# 842448   INSPIRE - Annex III - Soil - Soil map (1:25.000)
# 842449                     Topsoil Organic Carbon Content
#
#                                             description_1  \
# 3                                                       |
# 8                                                       |
# 6       The file contains 3,592 datasets. They compris...
# 11      The file contains 843 datasets. They comprise ...
# 7       Scaling with ranked subsampling (SRS) is an al...
# ...                                                   ...
# 594961  This dataset contains the Soil map of the Gran...
# 838076  Modeling of the content of topsoil organic car...
# 838077  This dataset contains the Soil map of the Gran...
# 842448  This dataset contains the Soil map of the Gran...
# 842449  Modeling of the content of topsoil organic car...
#
#                                                keywords_1  \
# 3                           [Boden, infoMapAccessService]
# 8                           [Boden, infoMapAccessService]
# 6       [Soil, opendata, soil heterogeneity; proximal ...
# 11      [Soil, opendata, soil heterogeneity; proximal ...
# 7       [Soil, Bioinformatics, Computer programming, o...
# ...                                                   ...
# 594961      [Soil, INSPIRE, high-value-dataset, National]
# 838076      [Soil, INSPIRE, high-value-dataset, National]
# 838077      [Soil, INSPIRE, high-value-dataset, National]
# 842448      [Soil, INSPIRE, high-value-dataset, National]
# 842449      [Soil, INSPIRE, high-value-dataset, National]
#
#                                         id_2  \
# 3       68749995-c4bf-4f80-94e5-43c2291c99be
# 8       5187f8c5-38ef-4b07-bc26-a5e257a8ef59
# 6       7a740815-f3bf-461f-a8d3-b7e274d3aac2
# 11      b8311ee8-4b8f-421a-aeac-2b4f0d4beff8
# 7       9730f571-96c7-4490-b5c2-e99d4c63f572
# ...                                      ...
# 594961  BD518FF7-C525-4250-B28C-BD4B8D884393
# 838076  43ACDDFF-4F47-443E-B697-D36330486A75
# 838077  6B346278-D020-48BE-9617-CE8BA1513308
# 842448  6B346278-D020-48BE-9617-CE8BA1513308
# 842449  68B4F032-A0CE-4B47-89C2-23DB80414102
#
#                                                   title_2  \
# 3                                                       |
# 8                                                       |
# 6       On-the-go gamma spectra for the site “Düren” f...
# 11      On-the-go gamma spectra for the site “Düren” f...
# 7       Scaling with ranked subsampling (SRS) algorith...
# ...                                                   ...
# 594961                             Soil acidity (pHCaCl2)
# 838076  INSPIRE - Annex III - Soil - Soil map (1:100.000)
# 838077                     Topsoil Organic Carbon Content
# 842448                     Topsoil Organic Carbon Content
# 842449   INSPIRE - Annex III - Soil - Soil map (1:25.000)
#
#                                             description_2  \
# 3                                                       |
# 8                                                       |
# 6       The file contains 843 datasets. They comprise ...
# 11      The file contains 3,592 datasets. They compris...
# 7       --This data has been withdrawn by the author.-...
# ...                                                   ...
# 594961  Interpolation (Kriging) of the pH content (CaC...
# 838076  This dataset contains the Soil map of the Gran...
# 838077  Modeling of the content of topsoil organic car...
# 842448  Modeling of the content of topsoil organic car...
# 842449  This dataset contains the Soil map of the Gran...
#
#                                                keywords_2
# 3                           [Boden, infoMapAccessService]
# 8                           [Boden, infoMapAccessService]
# 6       [Soil, opendata, soil heterogeneity; proximal ...
# 11      [Soil, opendata, soil heterogeneity; proximal ...
# 7       [Bioinformatics, statistics, Statistical metho...
# ...                                                   ...
# 594961      [Soil, INSPIRE, high-value-dataset, National]
# 838076      [Soil, INSPIRE, high-value-dataset, National]
# 838077      [Soil, INSPIRE, high-value-dataset, National]
# 842448      [Soil, INSPIRE, high-value-dataset, National]
# 842449      [Soil, INSPIRE, high-value-dataset, National]
#
# [1182 rows x 11 columns]

# %%
# Export the DataFrame to a CSV file
stacked_sim_df.to_csv('duplicate_datasheet_soilwise_cosinesim.csv', sep='\t', index=False)
